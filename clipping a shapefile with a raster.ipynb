# %%
##%pylab inline
from osgeo import gdal
import numpy as np
import os
import matplotlib.pyplot as plt
from PIL import Image
import shapefile

# %%
cd D:\Python\Shape
# Out:
# D:\Python\Shape

# %%
ls
# Out:
#  El volumen de la unidad D es Datos
#  El n£mero de serie del volumen es: B012-2E11
#
#  Directorio de D:\Python\Shape
#
# 01/04/2017  11:23 a. m.    <DIR>          .
# 01/04/2017  11:23 a. m.    <DIR>          ..
# 24/09/2016  08:29 p. m.               238 disolv.dbf
# 24/09/2016  08:29 p. m.               397 disolv.prj
# 24/09/2016  08:29 p. m.               606 disolv.qpj
# 24/09/2016  08:29 p. m.            40,236 disolv.shp
# 24/09/2016  08:29 p. m.               108 disolv.shx
# 07/07/2009  10:57 a. m.            90,302 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.dbf
# 10/12/2016  08:32 p. m.               409 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.prj
# 14/04/2010  11:16 a. m.             2,372 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.sbn
# 14/04/2010  11:16 a. m.               292 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.sbx
# 14/04/2010  11:15 a. m.        20,430,920 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.shp
# 18/01/2010  12:18 p. m.           154,279 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.shp.xml
# ...

# %%
shp=shapefile.Reader("disolv.shp")
shp1=shapefile.Reader("TEM_HIDRO_CUENCAS_HIDROGRAFICAS.shp")

# %%
ls
# Out:
#  El volumen de la unidad D es Datos
#  El n£mero de serie del volumen es: B012-2E11
#
#  Directorio de D:\Python\Shape
#
# 01/04/2017  11:23 a. m.    <DIR>          .
# 01/04/2017  11:23 a. m.    <DIR>          ..
# 24/09/2016  08:29 p. m.               238 disolv.dbf
# 24/09/2016  08:29 p. m.               397 disolv.prj
# 24/09/2016  08:29 p. m.               606 disolv.qpj
# 24/09/2016  08:29 p. m.            40,236 disolv.shp
# 24/09/2016  08:29 p. m.               108 disolv.shx
# 07/07/2009  10:57 a. m.            90,302 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.dbf
# 10/12/2016  08:32 p. m.               409 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.prj
# 14/04/2010  11:16 a. m.             2,372 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.sbn
# 14/04/2010  11:16 a. m.               292 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.sbx
# 14/04/2010  11:15 a. m.        20,430,920 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.shp
# 18/01/2010  12:18 p. m.           154,279 TEM_HIDRO_CUENCAS_HIDROGRAFICAS.shp.xml
# ...

# %%
shp.fields
# Out:
# [('DeletionFlag', 'C', 1, 0),
#  ['PROCOD98', 'C', 4, 0],
#  ['DEPCOD', 'C', 2, 0],
#  ['PRONOM98', 'C', 35, 0],
#  ['DEPNOM', 'C', 35, 0]]

# %%
plt.figure()
for shape in shp.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y)
plt.show()

# %%
plt.figure()
for shape in shp1.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y)
plt.show()
figsize(4,20)

# %%
os.chdir('D:\Python\Imagenes_landsat\Imagen-bofedales')
def openimage (TIF, indice):
    im=Image.open(TIF)
    imarray=np.array(im)
    imcut= imarray[4000:5000,5000:6000]
    im.close()
    return imcut

# %%
a= os.listdir(os.getcwd())
arreglogrande = np.zeros(shape=(1000,1000,11))
for item in range(len(a)-1): arreglogrande[:,:,item]=openimage(a[item],item)
# Out:
# C:\Users\Stiben\Anaconda2\lib\site-packages\PIL\Image.py:2371: DecompressionBombWarning: Image size (236555561 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning)

# %%
plt.figure()
for shape in shp.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y)
    figsize(4,5)
plt.show()
imshow(arreglogrande[:,:,5])

# %%
# Out:
# ['B1.tif', 'Imagen-bofedales', 'LC80060692016185LGN00.tar.gz']
